# %% [markdown]
# <a href="https://colab.research.google.com/github/HausReport/ClubRaiders/blob/master/notebooks/FactionDetails.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys 

# !{sys.executable} -m pip install --force-reinstall --upgrade "git+https://github.com/HausReport/ClubRaiders.git#egg=craid"
import craid.eddb.loader.DataProducer as dp
import pandas as pd
import logging
import plotly.graph_objs as go
from numpy import *


logging.getLogger().addHandler(logging.StreamHandler())
logging.getLogger().level = logging.DEBUG

arrays = dp.getDataArrays()
df: pd.DataFrame = arrays['dataFrame'];
# Out:
# ...
#   Cloning https://github.com/HausReport/ClubRaiders.git to /tmp/pip-install-pi_vx7oi/craid
#   Running command git clone -q https://github.com/HausReport/ClubRaiders.git /tmp/pip-install-pi_vx7oi/craid
# ...
#      |████████████████████████████████| 71kB 2.0MB/s
# ...
#      |████████████████████████████████| 3.4MB 7.7MB/s
# ...
#      |████████████████████████████████| 194kB 30.7MB/s
# ...
#      |████████████████████████████████| 1.8MB 31.7MB/s
# ...
#      |████████████████████████████████| 1.2MB 32.5MB/s
# ...
#      |████████████████████████████████| 102kB 11.0MB/s
# ...
#      |████████████████████████████████| 10.1MB 40.1MB/s
# ...
#      |████████████████████████████████| 61kB 7.9MB/s
# ...
#      |████████████████████████████████| 583kB 50.0MB/s
# ...
#      |████████████████████████████████| 20.1MB 1.3MB/s
# ...
#      |████████████████████████████████| 235kB 32.9MB/s
# ...
#      |████████████████████████████████| 184kB 43.7MB/s
# ...
#      |████████████████████████████████| 133kB 44.6MB/s
# ...
#      |████████████████████████████████| 450kB 37.2MB/s
# ...

# %%
n_by_sys = df.groupby("factionName")[["factionName","systemName","population","influence"]].agg({'factionName': 'first', 'systemName': 'count', 'population': 'sum', 'influence': 'sum'})
n_by_sys.columns = [ 'Faction Name','Systems', 'Population', 'Total Influence']
n_by_sys
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                                           Faction Name  ...  Total Influence
# factionName                                             ...
# Abroin Universal PLC              Abroin Universal PLC  ...         168.0200
# Aegis Core                                  Aegis Core  ...          39.9815
# Aegis Defense                            Aegis Defense  ...           0.0000
# Aegis Research                          Aegis Research  ...         175.3048
# Benton's Gang                            Benton's Gang  ...           3.9000
# Bentonian Party                        Bentonian Party  ...          26.2021
# Bill Turner                                Bill Turner  ...           0.0000
# CQC Holdings                              CQC Holdings  ...         280.9340
# ...

# %%
df
# Out:
#                     systemName  ...    regionNumber
# 0                      64 Ceti  ...  rgb(255,255,0)
# 1                       Abroin  ...  rgb(0,255,255)
# 2                       Akandi  ...  rgb(0, 255, 0)
# 3                       Alioth  ...      rgb(0,0,0)
# 4                       Alioth  ...      rgb(0,0,0)
# ..                         ...  ...             ...
# 182                   33 Cygni  ...      rgb(0,0,0)
# 183  Col 285 Sector BQ-N c7-13  ...  rgb(255,0,255)
# 184    Mel 22 Sector GM-V c2-8  ...      rgb(0,0,0)
# 185                     Delphi  ...  rgb(255, 0, 0)
# 186                     Delphi  ...  rgb(255, 0, 0)
#
# [187 rows x 22 columns]

# %%
df[df["vulnerable"].str.contains("War")]["systemName"].nunique()
# Out:
# 2

# %%
df[df["difficulty"]<=1.0]["systemName"].nunique()
# Out:
# 56

# %%
df["population"].sum()
# Out:
# 95480545325

# %%
n_by_sys = df.groupby("systemName")[["systemName","population"]].agg({'systemName': 'first', 'population': 'first'})

# %%
n_by_sys["population"].sum()
# Out:
# 80567893825

# %%
n_by_sys["systemName"].count()
# Out:
# 172
